# %%
from sklearn import datasets
import matplotlib.pyplot as plt
import heapq
import numpy as np

# %%
moon = datasets.make_moons(256, noise =0.06)
plt.figure(figsize=(12,6))
plt.scatter(moon[0][:,0:1].reshape(-1), moon[0][:,1:2].reshape(-1),color='r',s=10)
plt.show()

# %%
biclusters = datasets.make_biclusters((128,128),2,noise=15)
plt.scatter(biclusters[0][:,0:1].reshape(-1),biclusters[0][:,1:2].reshape(-1),color='r')
plt.show()

# %%
index_list = []
for i in a:
    b = -1*np.sqrt(np.sum(np.square(i-a),axis=1))
    index_list.append(heapq.nlargest(4, range(len(b)),b.take))

# %%
b.take
# Out:
# <function ndarray.take>

# %%
W = np.zeros((256,256))

# %%
for i in index_list:
    if i[0] in index_list[i[1]]:
        W[i[0]][i[1]] = 1
    if i[0] in index_list[i[2]]:
        W[i[0]][i[2]] = 1
    if i[0] in index_list[i[3]]:
        W[i[0]][i[3]] = 1

# %%
x=[2,4,6,7,8,5,4,3]
y=[3,6,5,8,4,3,2,4]
txt=['1','2','3','4','5','6','7','8']
# plt.rcParams['font.sans-serif']=['SimHei']
plt.scatter(x,y,s=300,alpha=0.5,c="red")
for i in range(len(x)):
    plt.annotate(txt[i],xy=(x[i],y[i]),xytext=(x[i]-0.06,y[i]-0.09))
plt.axis("off")
plt.show()
